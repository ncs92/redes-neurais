# %%
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD

import numpy as np
import csv

#fixar a semente pra sempre obter os mesmos resultados
#N sei se funciona perfeitamente com a train_test_split
np.random.seed(7) 

from tensorflow.python.client import device_lib
reader = csv.reader(open('OnlineNewsPopularity.csv','r'), delimiter=',')

rows = np.array(list(reader))
labels = rows[1, 1:-2]
X = rows[1:-1, 1:-2] 
Ya = rows[1:-1, -1] #ultima coluna
#print(rows)
Y = []

index = 0

for y in Ya:
    if(int(y) > 1200):
        Y.insert(index, True)
        
    else:
        Y.insert(index, False)
    
    index += 1
#print(rows)

# print(labels)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y)
#X_train, X_validation, Y_train, Y_validation = train_test_split(X_train, Y_train, test_size=0.2, stratify=Y_train)

########################### TESTE ################################

model = Sequential()
qnt_entradas = len(labels)
model.add(Dense(128, input_dim=qnt_entradas, init='uniform', activation='relu'))

model.add(Dense(128, init='uniform', activation='relu'))
model.add(Dense(128, init='uniform', activation='relu'))

model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']) #adam = descida do gradiente
model.fit(X_train, Y_train, nb_epoch=50, batch_size=10)
scores = model.evaluate(X_test, Y_test)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print(qnt_entradas)
#train_test_split()
#print(labels)
# Out:
# /home/frozza/.local/lib/python2.7/site-packages/ipykernel_launcher.py:44: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(128, activation="relu", kernel_initializer="uniform", input_dim=58)`
# /home/frozza/.local/lib/python2.7/site-packages/ipykernel_launcher.py:46: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(128, activation="relu", kernel_initializer="uniform")`
# /home/frozza/.local/lib/python2.7/site-packages/ipykernel_launcher.py:47: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(128, activation="relu", kernel_initializer="uniform")`
# /home/frozza/.local/lib/python2.7/site-packages/ipykernel_launcher.py:52: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Epoch 1/50
# 31714/31714 [==============================] - 7s 223us/step - loss: 9.1664 - acc: 0.4311
# Epoch 2/50
# 31714/31714 [==============================] - 5s 150us/step - loss: 9.3078 - acc: 0.4225
# Epoch 3/50
# 31714/31714 [==============================] - 5s 168us/step - loss: 9.3078 - acc: 0.4225
# Epoch 4/50
# 31714/31714 [==============================] - 7s 235us/step - loss: 9.3078 - acc: 0.4225
# Epoch 5/50
# 31714/31714 [==============================] - 7s 236us/step - loss: 9.3078 - acc: 0.4225
# Epoch 6/50
# 31714/31714 [==============================] - 7s 236us/step - loss: 9.3078 - acc: 0.4225
# Epoch 7/50
# 31714/31714 [==============================] - 8s 237us/step - loss: 9.3078 - acc: 0.4225
# Epoch 8/50
# 31714/31714 [==============================] - 8s 237us/step - loss: 9.3078 - acc: 0.4225
# Epoch 9/50
# 31714/31714 [==============================] - 8s 238us/step - loss: 9.3078 - acc: 0.4225
# Epoch 10/50
# 31714/31714 [==============================] - 8s 237us/step - loss: 9.3078 - acc: 0.4225
# Epoch 11/50
# 31714/31714 [==============================] - 7s 236us/step - loss: 9.3078 - acc: 0.4225
# Epoch 12/50
# 31714/31714 [==============================] - 8s 240us/step - loss: 9.3078 - acc: 0.4225
# Epoch 13/50
# 31714/31714 [==============================] - 8s 238us/step - loss: 9.3078 - acc: 0.4225
# Epoch 14/50
# 31714/31714 [==============================] - 8s 240us/step - loss: 9.3078 - acc: 0.4225
# Epoch 15/50
# 31714/31714 [==============================] - 8s 239us/step - loss: 9.3078 - acc: 0.4225
# Epoch 16/50
# 31714/31714 [==============================] - 8s 239us/step - loss: 9.3078 - acc: 0.4225
# Epoch 17/50
# 31714/31714 [==============================] - 8s 239us/step - loss: 9.3078 - acc: 0.4225
# Epoch 18/50
